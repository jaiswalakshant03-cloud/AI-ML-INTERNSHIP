# %% [markdown]
# <a href="https://colab.research.google.com/github/jaiswalakshant03-cloud/AI-ML-INTERNSHIP/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Student_ID": [101,102,103,104,105,106,107,108,109,110,
                   111,112,113,114,115,116,117,118,119,120],

    "Name": ["Aman","Neha","Rahul","Priya","Karan",
             "Simran","Mohit","Anjali","Vikas","Pooja",
             "Rohit","Sneha","Arjun","Riya","Deepak",
             "Muskan","Yash","Komal","Abhishek","Nisha"],

    "Gender": ["Male","Female","Male","Female","Male",
               "Female","Male","Female","Male","Female",
               "Male","Female","Male","Female","Male",
               "Female","Male","Female","Male","Female"],

    "Age": [20,21,19,22,20,21,20,19,22,20,
            21,20,23,19,22,20,21,22,20,19],

    "Department": ["CSE","IT","ECE","CSE","IT",
                   "CSE","ECE","IT","CSE","ECE",
                   "IT","CSE","ECE","IT","CSE",
                   "ECE","IT","CSE","ECE","IT"],

    "Semester": [4,4,2,6,4,6,2,4,8,6,
                 2,8,6,4,8,2,6,4,8,2],

    "Marks": [85,92,78,95,67,88,72,91,81,76,
              69,94,73,89,97,66,82,90,79,84],

    "Attendance": [92,95,85,97,78,90,82,98,88,84,
                   80,96,83,91,99,76,89,94,87,92],

    "CGPA": [8.5,9.2,7.8,9.5,6.9,
             8.8,7.2,9.1,8.1,7.6,
             7.0,9.4,7.4,8.9,9.8,
             6.8,8.2,9.0,7.9,8.4],

    "City": ["Delhi","Lucknow","Noida","Jaipur","Delhi",
             "Noida","Lucknow","Delhi","Jaipur","Delhi",
             "Noida","Lucknow","Delhi","Jaipur","Delhi",
             "Noida","Lucknow","Delhi","Jaipur","Delhi"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101      Aman    Male   20        CSE         4     85          92
# 1          102      Neha  Female   21         IT         4     92          95
# 2          103     Rahul    Male   19        ECE         2     78          85
# 3          104     Priya  Female   22        CSE         6     95          97
# 4          105     Karan    Male   20         IT         4     67          78
# 5          106    Simran  Female   21        CSE         6     88          90
# 6          107     Mohit    Male   20        ECE         2     72          82
# 7          108    Anjali  Female   19         IT         4     91          98
# 8          109     Vikas    Male   22        CSE         8     81          88
# 9          110     Pooja  Female   20        ECE         6     76          84
# 10         111     Rohit    Male   21         IT         2     69          80
# 11         112     Sneha  Female   20        CSE         8     94          96
# 12         113     Arjun    Male   23        ECE         6     73          83
# 13         114      Riya  Female   19         IT         4     89          91
# 14         115    Deepak    Male   22        CSE         8     97          99
# 15         116    Muskan  Female   20        ECE         2     66          76
# 16         117      Yash    Male   21         IT         6     82          89
# 17         118     Komal  Female   22        CSE         4     90          94
# 18         119  Abhishek    Male   20        ECE         8     79          87
# 19         120     Nisha  Female   19         IT         2     84          92
#
#     CGPA     City
# 0    8.5    Delhi
# 1    9.2  Lucknow
# 2    7.8    Noida
# 3    9.5   Jaipur
# 4    6.9    Delhi
# 5    8.8    Noida
# 6    7.2  Lucknow
# 7    9.1    Delhi
# 8    8.1   Jaipur
# 9    7.6    Delhi
# 10   7.0    Noida
# 11   9.4  Lucknow
# 12   7.4    Delhi
# 13   8.9   Jaipur
# 14   9.8    Delhi
# 15   6.8    Noida
# 16   8.2  Lucknow
# 17   9.0    Delhi
# 18   7.9   Jaipur
# 19   8.4    Delhi

# %%
df
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101      Aman    Male   20        CSE         4     85          92
# 1          102      Neha  Female   21         IT         4     92          95
# 2          103     Rahul    Male   19        ECE         2     78          85
# 3          104     Priya  Female   22        CSE         6     95          97
# 4          105     Karan    Male   20         IT         4     67          78
# 5          106    Simran  Female   21        CSE         6     88          90
# 6          107     Mohit    Male   20        ECE         2     72          82
# 7          108    Anjali  Female   19         IT         4     91          98
# 8          109     Vikas    Male   22        CSE         8     81          88
# 9          110     Pooja  Female   20        ECE         6     76          84
# 10         111     Rohit    Male   21         IT         2     69          80
# 11         112     Sneha  Female   20        CSE         8     94          96
# 12         113     Arjun    Male   23        ECE         6     73          83
# 13         114      Riya  Female   19         IT         4     89          91
# 14         115    Deepak    Male   22        CSE         8     97          99
# 15         116    Muskan  Female   20        ECE         2     66          76
# 16         117      Yash    Male   21         IT         6     82          89
# 17         118     Komal  Female   22        CSE         4     90          94
# 18         119  Abhishek    Male   20        ECE         8     79          87
# 19         120     Nisha  Female   19         IT         2     84          92
#
#     CGPA     City
# 0    8.5    Delhi
# 1    9.2  Lucknow
# 2    7.8    Noida
# 3    9.5   Jaipur
# 4    6.9    Delhi
# 5    8.8    Noida
# 6    7.2  Lucknow
# 7    9.1    Delhi
# 8    8.1   Jaipur
# 9    7.6    Delhi
# 10   7.0    Noida
# 11   9.4  Lucknow
# 12   7.4    Delhi
# 13   8.9   Jaipur
# 14   9.8    Delhi
# 15   6.8    Noida
# 16   8.2  Lucknow
# 17   9.0    Delhi
# 18   7.9   Jaipur
# 19   8.4    Delhi

# %%
df.head()
# Out:
#    Student_ID   Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0         101   Aman    Male   20        CSE         4     85          92
# 1         102   Neha  Female   21         IT         4     92          95
# 2         103  Rahul    Male   19        ECE         2     78          85
# 3         104  Priya  Female   22        CSE         6     95          97
# 4         105  Karan    Male   20         IT         4     67          78
#
#    CGPA     City
# 0   8.5    Delhi
# 1   9.2  Lucknow
# 2   7.8    Noida
# 3   9.5   Jaipur
# 4   6.9    Delhi

# %%
df.tail()
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 15         116    Muskan  Female   20        ECE         2     66          76
# 16         117      Yash    Male   21         IT         6     82          89
# 17         118     Komal  Female   22        CSE         4     90          94
# 18         119  Abhishek    Male   20        ECE         8     79          87
# 19         120     Nisha  Female   19         IT         2     84          92
#
#     CGPA     City
# 15   6.8    Noida
# 16   8.2  Lucknow
# 17   9.0    Delhi
# 18   7.9   Jaipur
# 19   8.4    Delhi

# %%
df.sample()
# Out:
#    Student_ID   Name Gender  Age Department  Semester  Marks  Attendance  \
# 8         109  Vikas   Male   22        CSE         8     81          88
#
#    CGPA    City
# 8   8.1  Jaipur

# %%
df.shape
# Out:
# (20, 10)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Gender', 'Age', 'Department', 'Semester',
#        'Marks', 'Attendance', 'CGPA', 'City'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Student_ID      int64
# Name           object
# Gender         object
# Age             int64
# Department     object
# Semester        int64
# Marks           int64
# Attendance      int64
# CGPA          float64
# City           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  20 non-null     int64
#  1   Name        20 non-null     object
#  2   Gender      20 non-null     object
#  3   Age         20 non-null     int64
#  4   Department  20 non-null     object
#  5   Semester    20 non-null     int64
#  6   Marks       20 non-null     int64
#  7   Attendance  20 non-null     int64
#  8   CGPA        20 non-null     float64
#  9   City        20 non-null     object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.7+ KB

# %%
df["Semester"].describe()
# Out:
# count    20.00000
# mean      4.80000
# std       2.19089
# min       2.00000
# 25%       3.50000
# 50%       4.00000
# 75%       6.00000
# max       8.00000
# Name: Semester, dtype: float64

# %%
df.sort_values("Age") #ascending sorting
df.sort_values("Age",ascending=False) #descending order
df.sort_values(["Name","Age"]) #multiple column sorting
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 18         119  Abhishek    Male   20        ECE         8     79          87
# 0          101      Aman    Male   20        CSE         4     85          92
# 7          108    Anjali  Female   19         IT         4     91          98
# 12         113     Arjun    Male   23        ECE         6     73          83
# 14         115    Deepak    Male   22        CSE         8     97          99
# 4          105     Karan    Male   20         IT         4     67          78
# 17         118     Komal  Female   22        CSE         4     90          94
# 6          107     Mohit    Male   20        ECE         2     72          82
# 15         116    Muskan  Female   20        ECE         2     66          76
# 1          102      Neha  Female   21         IT         4     92          95
# 19         120     Nisha  Female   19         IT         2     84          92
# 9          110     Pooja  Female   20        ECE         6     76          84
# 3          104     Priya  Female   22        CSE         6     95          97
# 2          103     Rahul    Male   19        ECE         2     78          85
# 13         114      Riya  Female   19         IT         4     89          91
# 10         111     Rohit    Male   21         IT         2     69          80
# 5          106    Simran  Female   21        CSE         6     88          90
# 11         112     Sneha  Female   20        CSE         8     94          96
# 8          109     Vikas    Male   22        CSE         8     81          88
# 16         117      Yash    Male   21         IT         6     82          89
#
#     CGPA     City
# 18   7.9   Jaipur
# 0    8.5    Delhi
# 7    9.1    Delhi
# 12   7.4    Delhi
# 14   9.8    Delhi
# 4    6.9    Delhi
# 17   9.0    Delhi
# 6    7.2  Lucknow
# 15   6.8    Noida
# 1    9.2  Lucknow
# 19   8.4    Delhi
# 9    7.6    Delhi
# 3    9.5   Jaipur
# 2    7.8    Noida
# 13   8.9   Jaipur
# 10   7.0    Noida
# 5    8.8    Noida
# 11   9.4  Lucknow
# 8    8.1   Jaipur
# 16   8.2  Lucknow

# %%
df
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101      Aman    Male   20        CSE         4     85          92
# 1          102      Neha  Female   21         IT         4     92          95
# 2          103     Rahul    Male   19        ECE         2     78          85
# 3          104     Priya  Female   22        CSE         6     95          97
# 4          105     Karan    Male   20         IT         4     67          78
# 5          106    Simran  Female   21        CSE         6     88          90
# 6          107     Mohit    Male   20        ECE         2     72          82
# 7          108    Anjali  Female   19         IT         4     91          98
# 8          109     Vikas    Male   22        CSE         8     81          88
# 9          110     Pooja  Female   20        ECE         6     76          84
# 10         111     Rohit    Male   21         IT         2     69          80
# 11         112     Sneha  Female   20        CSE         8     94          96
# 12         113     Arjun    Male   23        ECE         6     73          83
# 13         114      Riya  Female   19         IT         4     89          91
# 14         115    Deepak    Male   22        CSE         8     97          99
# 15         116    Muskan  Female   20        ECE         2     66          76
# 16         117      Yash    Male   21         IT         6     82          89
# 17         118     Komal  Female   22        CSE         4     90          94
# 18         119  Abhishek    Male   20        ECE         8     79          87
# 19         120     Nisha  Female   19         IT         2     84          92
#
#     CGPA     City
# 0    8.5    Delhi
# 1    9.2  Lucknow
# 2    7.8    Noida
# 3    9.5   Jaipur
# 4    6.9    Delhi
# 5    8.8    Noida
# 6    7.2  Lucknow
# 7    9.1    Delhi
# 8    8.1   Jaipur
# 9    7.6    Delhi
# 10   7.0    Noida
# 11   9.4  Lucknow
# 12   7.4    Delhi
# 13   8.9   Jaipur
# 14   9.8    Delhi
# 15   6.8    Noida
# 16   8.2  Lucknow
# 17   9.0    Delhi
# 18   7.9   Jaipur
# 19   8.4    Delhi

# %%
df["Name"]
# Out:
# 0         Aman
# 1         Neha
# 2        Rahul
# 3        Priya
# 4        Karan
# 5       Simran
# 6        Mohit
# 7       Anjali
# 8        Vikas
# 9        Pooja
# 10       Rohit
# 11       Sneha
# 12       Arjun
# 13        Riya
# 14      Deepak
# 15      Muskan
# 16        Yash
# 17       Komal
# 18    Abhishek
# 19       Nisha
# Name: Name, dtype: object

# %%
df[df['CGPA']>7.0]
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101      Aman    Male   20        CSE         4     85          92
# 1          102      Neha  Female   21         IT         4     92          95
# 2          103     Rahul    Male   19        ECE         2     78          85
# 3          104     Priya  Female   22        CSE         6     95          97
# 5          106    Simran  Female   21        CSE         6     88          90
# 6          107     Mohit    Male   20        ECE         2     72          82
# 7          108    Anjali  Female   19         IT         4     91          98
# 8          109     Vikas    Male   22        CSE         8     81          88
# 9          110     Pooja  Female   20        ECE         6     76          84
# 11         112     Sneha  Female   20        CSE         8     94          96
# 12         113     Arjun    Male   23        ECE         6     73          83
# 13         114      Riya  Female   19         IT         4     89          91
# 14         115    Deepak    Male   22        CSE         8     97          99
# 16         117      Yash    Male   21         IT         6     82          89
# 17         118     Komal  Female   22        CSE         4     90          94
# 18         119  Abhishek    Male   20        ECE         8     79          87
# 19         120     Nisha  Female   19         IT         2     84          92
#
#     CGPA     City
# 0    8.5    Delhi
# 1    9.2  Lucknow
# 2    7.8    Noida
# 3    9.5   Jaipur
# 5    8.8    Noida
# 6    7.2  Lucknow
# 7    9.1    Delhi
# 8    8.1   Jaipur
# 9    7.6    Delhi
# 11   9.4  Lucknow
# 12   7.4    Delhi
# 13   8.9   Jaipur
# 14   9.8    Delhi
# 16   8.2  Lucknow
# 17   9.0    Delhi
# 18   7.9   Jaipur
# 19   8.4    Delhi

# %%
df[(df["CGPA"]>7.0)&(df['Department']=="CSE")]
# Out:
#     Student_ID    Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101    Aman    Male   20        CSE         4     85          92
# 3          104   Priya  Female   22        CSE         6     95          97
# 5          106  Simran  Female   21        CSE         6     88          90
# 8          109   Vikas    Male   22        CSE         8     81          88
# 11         112   Sneha  Female   20        CSE         8     94          96
# 14         115  Deepak    Male   22        CSE         8     97          99
# 17         118   Komal  Female   22        CSE         4     90          94
#
#     CGPA     City
# 0    8.5    Delhi
# 3    9.5   Jaipur
# 5    8.8    Noida
# 8    8.1   Jaipur
# 11   9.4  Lucknow
# 14   9.8    Delhi
# 17   9.0    Delhi

# %%
df.sort_values("CGPA")
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 15         116    Muskan  Female   20        ECE         2     66          76
# 4          105     Karan    Male   20         IT         4     67          78
# 10         111     Rohit    Male   21         IT         2     69          80
# 6          107     Mohit    Male   20        ECE         2     72          82
# 12         113     Arjun    Male   23        ECE         6     73          83
# 9          110     Pooja  Female   20        ECE         6     76          84
# 2          103     Rahul    Male   19        ECE         2     78          85
# 18         119  Abhishek    Male   20        ECE         8     79          87
# 8          109     Vikas    Male   22        CSE         8     81          88
# 16         117      Yash    Male   21         IT         6     82          89
# 19         120     Nisha  Female   19         IT         2     84          92
# 0          101      Aman    Male   20        CSE         4     85          92
# 5          106    Simran  Female   21        CSE         6     88          90
# 13         114      Riya  Female   19         IT         4     89          91
# 17         118     Komal  Female   22        CSE         4     90          94
# 7          108    Anjali  Female   19         IT         4     91          98
# 1          102      Neha  Female   21         IT         4     92          95
# 11         112     Sneha  Female   20        CSE         8     94          96
# 3          104     Priya  Female   22        CSE         6     95          97
# 14         115    Deepak    Male   22        CSE         8     97          99
#
#     CGPA     City
# 15   6.8    Noida
# 4    6.9    Delhi
# 10   7.0    Noida
# 6    7.2  Lucknow
# 12   7.4    Delhi
# 9    7.6    Delhi
# 2    7.8    Noida
# 18   7.9   Jaipur
# 8    8.1   Jaipur
# 16   8.2  Lucknow
# 19   8.4    Delhi
# 0    8.5    Delhi
# 5    8.8    Noida
# 13   8.9   Jaipur
# 17   9.0    Delhi
# 7    9.1    Delhi
# 1    9.2  Lucknow
# 11   9.4  Lucknow
# 3    9.5   Jaipur
# 14   9.8    Delhi

# %%
df.sort_values("CGPA",ascending=False)
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 14         115    Deepak    Male   22        CSE         8     97          99
# 3          104     Priya  Female   22        CSE         6     95          97
# 11         112     Sneha  Female   20        CSE         8     94          96
# 1          102      Neha  Female   21         IT         4     92          95
# 7          108    Anjali  Female   19         IT         4     91          98
# 17         118     Komal  Female   22        CSE         4     90          94
# 13         114      Riya  Female   19         IT         4     89          91
# 5          106    Simran  Female   21        CSE         6     88          90
# 0          101      Aman    Male   20        CSE         4     85          92
# 19         120     Nisha  Female   19         IT         2     84          92
# 16         117      Yash    Male   21         IT         6     82          89
# 8          109     Vikas    Male   22        CSE         8     81          88
# 18         119  Abhishek    Male   20        ECE         8     79          87
# 2          103     Rahul    Male   19        ECE         2     78          85
# 9          110     Pooja  Female   20        ECE         6     76          84
# 12         113     Arjun    Male   23        ECE         6     73          83
# 6          107     Mohit    Male   20        ECE         2     72          82
# 10         111     Rohit    Male   21         IT         2     69          80
# 4          105     Karan    Male   20         IT         4     67          78
# 15         116    Muskan  Female   20        ECE         2     66          76
#
#     CGPA     City
# 14   9.8    Delhi
# 3    9.5   Jaipur
# 11   9.4  Lucknow
# 1    9.2  Lucknow
# 7    9.1    Delhi
# 17   9.0    Delhi
# 13   8.9   Jaipur
# 5    8.8    Noida
# 0    8.5    Delhi
# 19   8.4    Delhi
# 16   8.2  Lucknow
# 8    8.1   Jaipur
# 18   7.9   Jaipur
# 2    7.8    Noida
# 9    7.6    Delhi
# 12   7.4    Delhi
# 6    7.2  Lucknow
# 10   7.0    Noida
# 4    6.9    Delhi
# 15   6.8    Noida

# %%
df["CGPA"].max()
# Out:
# 9.8

# %%
df["CGPA"].min()
# Out:
# 6.8

# %%
df['Name'].count()
# Out:
# np.int64(20)

# %%
df["Department"].unique()
# Out:
# array(['CSE', 'IT', 'ECE'], dtype=object)

# %%
df["Department"].nunique()
# Out:
# 3

# %%
df.rename(columns={"Name":"Student_Name"},inplace=True)

# %%
df
# Out:
#     Student_ID Student_Name  Gender  Age Department  Semester  Marks  \
# 0          101         Aman    Male   20        CSE         4     85
# 1          102         Neha  Female   21         IT         4     92
# 2          103        Rahul    Male   19        ECE         2     78
# 3          104        Priya  Female   22        CSE         6     95
# 4          105        Karan    Male   20         IT         4     67
# 5          106       Simran  Female   21        CSE         6     88
# 6          107        Mohit    Male   20        ECE         2     72
# 7          108       Anjali  Female   19         IT         4     91
# 8          109        Vikas    Male   22        CSE         8     81
# 9          110        Pooja  Female   20        ECE         6     76
# 10         111        Rohit    Male   21         IT         2     69
# 11         112        Sneha  Female   20        CSE         8     94
# 12         113        Arjun    Male   23        ECE         6     73
# 13         114         Riya  Female   19         IT         4     89
# 14         115       Deepak    Male   22        CSE         8     97
# 15         116       Muskan  Female   20        ECE         2     66
# 16         117         Yash    Male   21         IT         6     82
# 17         118        Komal  Female   22        CSE         4     90
# 18         119     Abhishek    Male   20        ECE         8     79
# 19         120        Nisha  Female   19         IT         2     84
#
#     Attendance  CGPA     City
# 0           92   8.5    Delhi
# 1           95   9.2  Lucknow
# 2           85   7.8    Noida
# 3           97   9.5   Jaipur
# 4           78   6.9    Delhi
# 5           90   8.8    Noida
# 6           82   7.2  Lucknow
# 7           98   9.1    Delhi
# 8           88   8.1   Jaipur
# 9           84   7.6    Delhi
# 10          80   7.0    Noida
# 11          96   9.4  Lucknow
# 12          83   7.4    Delhi
# 13          91   8.9   Jaipur
# 14          99   9.8    Delhi
# 15          76   6.8    Noida
# 16          89   8.2  Lucknow
# 17          94   9.0    Delhi
# 18          87   7.9   Jaipur
# 19          92   8.4    Delhi

# %%
df.drop("Gender",axis=1,inplace=True)

# %%
df
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101      Aman    Male   20        CSE         4     85          92
# 1          102      Neha  Female   21         IT         4     92          95
# 2          103     Rahul    Male   19        ECE         2     78          85
# 3          104     Priya  Female   22        CSE         6     95          97
# 4          105     Karan    Male   20         IT         4     67          78
# 5          106    Simran  Female   21        CSE         6     88          90
# 6          107     Mohit    Male   20        ECE         2     72          82
# 7          108    Anjali  Female   19         IT         4     91          98
# 8          109     Vikas    Male   22        CSE         8     81          88
# 9          110     Pooja  Female   20        ECE         6     76          84
# 10         111     Rohit    Male   21         IT         2     69          80
# 11         112     Sneha  Female   20        CSE         8     94          96
# 12         113     Arjun    Male   23        ECE         6     73          83
# 13         114      Riya  Female   19         IT         4     89          91
# 14         115    Deepak    Male   22        CSE         8     97          99
# 15         116    Muskan  Female   20        ECE         2     66          76
# 16         117      Yash    Male   21         IT         6     82          89
# 17         118     Komal  Female   22        CSE         4     90          94
# 18         119  Abhishek    Male   20        ECE         8     79          87
# 19         120     Nisha  Female   19         IT         2     84          92
#
#     CGPA     City
# 0    8.5    Delhi
# 1    9.2  Lucknow
# 2    7.8    Noida
# 3    9.5   Jaipur
# 4    6.9    Delhi
# 5    8.8    Noida
# 6    7.2  Lucknow
# 7    9.1    Delhi
# 8    8.1   Jaipur
# 9    7.6    Delhi
# 10   7.0    Noida
# 11   9.4  Lucknow
# 12   7.4    Delhi
# 13   8.9   Jaipur
# 14   9.8    Delhi
# 15   6.8    Noida
# 16   8.2  Lucknow
# 17   9.0    Delhi
# 18   7.9   Jaipur
# 19   8.4    Delhi

# %%
df.isnull()
# Out:
#     Student_ID   Name  Gender    Age  Department  Semester  Marks  Attendance  \
# 0        False  False   False  False       False     False  False       False
# 1        False  False   False  False       False     False  False       False
# 2        False  False   False  False       False     False  False       False
# 3        False  False   False  False       False     False  False       False
# 4        False  False   False  False       False     False  False       False
# 5        False  False   False  False       False     False  False       False
# 6        False  False   False  False       False     False  False       False
# 7        False  False   False  False       False     False  False       False
# 8        False  False   False  False       False     False  False       False
# 9        False  False   False  False       False     False  False       False
# 10       False  False   False  False       False     False  False       False
# 11       False  False   False  False       False     False  False       False
# 12       False  False   False  False       False     False  False       False
# 13       False  False   False  False       False     False  False       False
# 14       False  False   False  False       False     False  False       False
# 15       False  False   False  False       False     False  False       False
# 16       False  False   False  False       False     False  False       False
# 17       False  False   False  False       False     False  False       False
# 18       False  False   False  False       False     False  False       False
# 19       False  False   False  False       False     False  False       False
#
#      CGPA   City
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
# 15  False  False
# 16  False  False
# 17  False  False
# 18  False  False
# 19  False  False

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df[df["Student_Name"]=="Rohit"]
# Out:
#     Student_ID Student_Name Gender  Age Department  Semester  Marks  \
# 10         111        Rohit   Male   21         IT         2     69
#
#     Attendance  CGPA   City
# 10          80   7.0  Noida
